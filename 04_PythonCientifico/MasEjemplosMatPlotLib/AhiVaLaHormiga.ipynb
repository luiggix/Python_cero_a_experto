# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
img=mpimg.imread('./ComputoCientificoPython3_OLD/04_PythonCientifico/hormiga.jpg')
imgplot=plt.imshow(img)
plt.title('$\int_a^b \phi dx = 0$')
# Out:
# Text(0.5,1,'$\\int_a^b \\phi dx = 0$')

# %%
lum_img = img[:,:,0]
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')
plt.colorbar()
